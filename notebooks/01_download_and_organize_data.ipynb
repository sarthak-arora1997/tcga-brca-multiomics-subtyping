# %% [markdown]
# # 01 - Download and Organize Data
#
# This notebook collates the RNA-seq gene count tables previously downloaded from the GDC portal, cleans a combined expression matrix, and saves the organized outputs under `data/processed/` for downstream analysis.

# %% [markdown]
# **Workflow overview**
#
# 1. Discover every `.tsv` expression file that lives inside the raw GDC download bundles (ignoring manifest `.txt` files).
# 2. Build a tidy manifest so we can trace each file back to its case identifier.
# 3. Load the TPM counts, align the genes across all samples, and write a single expression matrix that other notebooks can use.

# %%
from __future__ import annotations

import sys
from pathlib import Path

import pandas as pd


def find_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / 'README.md').exists():
            return candidate
    raise FileNotFoundError('Unable to locate repository root (README.md not found)')


PROJECT_ROOT = find_project_root(Path.cwd())
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import ProjectConfig

config = ProjectConfig()
RAW_DATA_DIR = config.raw_data_dir / 'star gene counts'
CLINICAL_DATA_DIR = config.clinical_data_dir
PROCESSED_DATA_DIR = config.processed_data_dir
PROCESSED_DATA_DIR.mkdir(parents=True, exist_ok=True)

RAW_DATA_DIR, CLINICAL_DATA_DIR, PROCESSED_DATA_DIR
# Out:
# (PosixPath('/Users/lennonmccartney/Desktop/tcga-brca-multiomics-subtyping/data/raw/star gene counts'),
#  PosixPath('/Users/lennonmccartney/Desktop/tcga-brca-multiomics-subtyping/data/raw/clinical data'),
#  PosixPath('/Users/lennonmccartney/Desktop/tcga-brca-multiomics-subtyping/data/processed'))

# %% [markdown]
# ## Discover downloaded expression bundles
#
# Each download bundle from GDC sits in its own UUID-named directory. We walk the tree, capture every `.tsv` file (ignoring plain `.txt` documents such as manifests), and track minimal metadata for reproducibility.

# %%
import pandas as pd
import json


def collect_expression_files(root: Path) -> pd.DataFrame:
    '''Return metadata for every RNA-seq expression TSV found under ``root``.'''

    records: list[dict[str, object]] = []
    bundle_dirs = sorted(p for p in root.iterdir() if p.is_dir())
    for bundle in bundle_dirs:
        for path in sorted(bundle.glob('*.tsv')):
            if path.name.lower().endswith('.txt'):
                continue
            relative = path.relative_to(root)
            records.append(
                {
                    'file_name': path.name,
                    'bundle_id': bundle.name,
                    'path': path,
                    'relative_path': relative.as_posix(),
                }
            )
    if not records:
        raise FileNotFoundError(f'No TSV files discovered under {root}')
    return pd.DataFrame.from_records(records)


expression_index = collect_expression_files(RAW_DATA_DIR)
print(f'Discovered {len(expression_index)} expression TSV files.')
expression_index.head()
# Out:
# Discovered 1197 expression TSV files.
#                                            file_name  \
# 0  ba295155-272e-43eb-9d6a-e4c9c392e68b.rna_seq.a...
# 1  8d1641ea-7552-4d23-9298-094e0056386a.rna_seq.a...
# 2  2f51534b-248b-4999-bc3f-e42a2e98332e.rna_seq.a...
# 3  b321a3f5-043d-42c6-8c9d-5784d45cb85c.rna_seq.a...
# 4  cafc9e36-c5f0-45df-ad03-16210ff0d870.rna_seq.a...
#
#                               bundle_id  \
# 0  0019c951-16c5-48d0-85c8-58d96b12d330
# 1  0022cd20-f64f-4773-b9ff-a3de0b71b259
# 2  00469928-b243-4cae-acd7-134508e99ceb
# 3  0081f507-b104-4214-9ea1-31dd69130991
# 4  0094f9d0-45ec-4aad-bca0-71c60bdd7113
#
#                                                 path  \
# 0  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 1  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 2  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 3  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 4  /Users/lennonmccartney/Desktop/tcga-brca-multi...
#
#                                        relative_path
# 0  0019c951-16c5-48d0-85c8-58d96b12d330/ba295155-...
# 1  0022cd20-f64f-4773-b9ff-a3de0b71b259/8d1641ea-...
# 2  00469928-b243-4cae-acd7-134508e99ceb/2f51534b-...
# 3  0081f507-b104-4214-9ea1-31dd69130991/b321a3f5-...
# 4  0094f9d0-45ec-4aad-bca0-71c60bdd7113/cafc9e36-...

# %%
# Attach GDC metadata (JSON) to each expression file
metadata_path = PROJECT_ROOT / 'data' / 'raw' / 'clinical data' / 'metadata.cart.2025-12-07.json'
with metadata_path.open() as fh:
    metadata_records = json.load(fh)
metadata_df = pd.json_normalize(metadata_records)

def _expand_nested(metadata: pd.DataFrame, column: str, value_cols: list[str]) -> pd.DataFrame:
    exploded = metadata[['file_name', column]].explode(column)
    exploded = exploded.dropna(subset=[column])
    if exploded.empty:
        return pd.DataFrame(columns=['file_name', *value_cols])
    nested = exploded[column].apply(pd.Series)
    if nested is None or nested.empty:
        return pd.DataFrame(columns=['file_name', *value_cols])
    cols = ['file_name'] + [col for col in value_cols if col in nested.columns]
    if len(cols) == 1:
        return pd.DataFrame(columns=['file_name', *value_cols])
    expanded = pd.concat([exploded[['file_name']], nested[cols[1:]]], axis=1)
    grouped = (
        expanded.groupby('file_name').agg(
            lambda s: ';'.join(sorted({str(v) for v in s.dropna()}))
        )
    ).reset_index()
    for col in value_cols:
        if col not in grouped.columns:
            grouped[col] = ''
    return grouped

assoc_cols = ['entity_submitter_id', 'entity_type', 'case_id', 'entity_id']
assoc_df = _expand_nested(metadata_df, 'associated_entities', assoc_cols)
input_cols = ['access', 'submitter_id', 'data_category', 'file_id', 'data_type', 'experimental_strategy']
input_df = _expand_nested(metadata_df, 'analysis.input_files', input_cols)

metadata_filtered = assoc_df.merge(input_df, on='file_name', how='left')
expression_index = expression_index.merge(metadata_filtered, how='left', on='file_name')
print(f'Metadata-loaded expression manifest: {expression_index.shape[0]} rows, {expression_index.shape[1]} columns')
expression_index.head()
# Out:
# Metadata-loaded expression manifest: 1197 rows, 14 columns
#                                            file_name  \
# 0  ba295155-272e-43eb-9d6a-e4c9c392e68b.rna_seq.a...
# 1  8d1641ea-7552-4d23-9298-094e0056386a.rna_seq.a...
# 2  2f51534b-248b-4999-bc3f-e42a2e98332e.rna_seq.a...
# 3  b321a3f5-043d-42c6-8c9d-5784d45cb85c.rna_seq.a...
# 4  cafc9e36-c5f0-45df-ad03-16210ff0d870.rna_seq.a...
#
#                               bundle_id  \
# 0  0019c951-16c5-48d0-85c8-58d96b12d330
# 1  0022cd20-f64f-4773-b9ff-a3de0b71b259
# 2  00469928-b243-4cae-acd7-134508e99ceb
# 3  0081f507-b104-4214-9ea1-31dd69130991
# 4  0094f9d0-45ec-4aad-bca0-71c60bdd7113
#
#                                                 path  \
# 0  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 1  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 2  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 3  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 4  /Users/lennonmccartney/Desktop/tcga-brca-multi...
#
#                                        relative_path  \
# 0  0019c951-16c5-48d0-85c8-58d96b12d330/ba295155-...
# 1  0022cd20-f64f-4773-b9ff-a3de0b71b259/8d1641ea-...
# 2  00469928-b243-4cae-acd7-134508e99ceb/2f51534b-...
# 3  0081f507-b104-4214-9ea1-31dd69130991/b321a3f5-...
# 4  0094f9d0-45ec-4aad-bca0-71c60bdd7113/cafc9e36-...
#
#             entity_submitter_id entity_type  \
# 0  TCGA-D8-A1XO-01A-11R-A14M-07     aliquot
# 1  TCGA-AN-A0FN-01A-11R-A034-07     aliquot
# 2  TCGA-AC-A62X-01A-11R-A29R-07     aliquot
# 3  TCGA-E2-A14U-01A-11R-A22K-07     aliquot
# 4  TCGA-E9-A1R3-01A-31R-A14M-07     aliquot
#
#                                 case_id                             entity_id  \
# 0  6a186809-3422-41d0-83d2-867145830936  eddd285e-a946-4e4e-a21d-6e84ed397594
# 1  c2a742fe-3e8b-4210-85a6-7191a1123609  4aac7c40-db6b-4648-a82a-7bf397de913a
# 2  5b2a4f11-ca46-4974-9420-59b4820920bf  cdc523d2-da82-4a3d-a97e-9745c8a802d1
# 3  23b7aaea-1119-4b10-aa1a-0ae255d2f2a6  20d25e27-b509-45eb-a734-9b8d6a40c632
# 4  4922cddc-575c-4b8a-8245-ce5f6876760c  678ba111-3b01-49b7-83d9-165ef0288a34
#
#        access                          submitter_id     data_category  \
# 0  controlled  0e68b49d-a54d-41c3-a5f7-13fc141ab0e8  Sequencing Reads
# 1  controlled  fd4c1bc5-6eab-4830-9178-afbab6a7a954  Sequencing Reads
# 2  controlled  6920521e-f04a-4ae1-b161-df65804500b6  Sequencing Reads
# 3  controlled  f8ed6c74-0202-4ac0-a581-b00c504e9e4b  Sequencing Reads
# 4  controlled  71af5a94-601d-4710-834a-ee8ac0265d20  Sequencing Reads
#
#                                 file_id      data_type experimental_strategy
# 0  cb7714fd-20e5-4ecf-9498-591e0c1fdcde  Aligned Reads               RNA-Seq
# 1  786b6363-889b-4437-8830-eac79e5a8d5b  Aligned Reads               RNA-Seq
# 2  2cd40ce3-5054-452e-bd21-854fdcd3646b  Aligned Reads               RNA-Seq
# 3  5d613c10-ab5c-4ab4-a42a-5f68de579ca3  Aligned Reads               RNA-Seq
# 4  bcecf315-bca9-4518-ace3-dad827722905  Aligned Reads               RNA-Seq

# %%
expression_index[expression_index["entity_submitter_id"].str.contains("TCGA-A7-A0DA")]
# Out:
#                                              file_name  \
# 244  acda1855-14ba-4e05-89f7-50f7823f38b3.rna_seq.a...
#
#                                 bundle_id  \
# 244  3293a2fa-d57c-448e-a336-a92def5dd92a
#
#                                                   path  \
# 244  /Users/lennonmccartney/Desktop/tcga-brca-multi...
#
#                                          relative_path  \
# 244  3293a2fa-d57c-448e-a336-a92def5dd92a/acda1855-...
#
#               entity_submitter_id entity_type  \
# 244  TCGA-A7-A0DA-01A-31R-A115-07     aliquot
#
#                                   case_id  \
# 244  3afa1e93-1df8-4e4c-aaa4-557463f4bb77
#
#                                 entity_id      access  \
# 244  9d04c180-7c23-490e-92cf-c018629b8b7f  controlled
#
#                              submitter_id     data_category  \
# 244  9adb99e0-713d-494c-ba49-5d47c793c9ff  Sequencing Reads
#
#                                   file_id      data_type experimental_strategy
# 244  f407d453-5436-4348-9bec-397baad34adf  Aligned Reads               RNA-Seq

# %%
# Load biospecimen cart metadata (JSON)
biospecimen_metadata_path = PROJECT_ROOT / 'data' / 'raw' / 'clinical data' / 'biospecimen.cart.2025-12-07.json'
with biospecimen_metadata_path.open() as fh:
    biospecimen_metadata_records = json.load(fh)
biospecimen_metadata_df = pd.json_normalize(biospecimen_metadata_records)
print(f'Biospecimen metadata rows: {len(biospecimen_metadata_df)}; columns: {biospecimen_metadata_df.shape[1]}')
biospecimen_metadata_df.head()
# Out:
# Biospecimen metadata rows: 1095; columns: 4
#                                 case_id  submitter_id  \
# 0  001cef41-ff86-4d3f-a140-a647ac4b10a1  TCGA-E2-A1IU
# 1  0045349c-69d9-4306-a403-c9c1fa836644  TCGA-A1-A0SB
# 2  00807dae-9f4a-4fd1-aac2-82eb11bf2afb  TCGA-A2-A04W
# 3  00a2d166-78c9-4687-a195-3d6315c27574  TCGA-AN-A0AM
# 4  00b11ca8-8540-4a3d-b602-ec754b00230b  TCGA-LL-A440
#
#                                              samples project.project_id
# 0  [{'tumor_descriptor': 'Primary', 'specimen_typ...          TCGA-BRCA
# 1  [{'tumor_descriptor': 'Not Applicable', 'speci...          TCGA-BRCA
# 2  [{'tumor_descriptor': 'Not Applicable', 'speci...          TCGA-BRCA
# 3  [{'tumor_descriptor': 'Primary', 'sample_id': ...          TCGA-BRCA
# 4  [{'tumor_descriptor': 'Primary', 'specimen_typ...          TCGA-BRCA

# %%
# Inspect nested samples/portions/analytes (Aliquots within analytes)/slides for one biospecimen record
sample_record = biospecimen_metadata_df.iloc[0]
samples_expanded = pd.json_normalize(sample_record['samples'])
print('Samples columns:', samples_expanded.columns.tolist())
sample_with_portions = samples_expanded.iloc[2]
portions_expanded = pd.json_normalize(sample_with_portions['portions'])
print('Portions columns:', portions_expanded.columns.tolist())
portion_with_analytes = portions_expanded.iloc[0]
analytes_expanded = pd.json_normalize(portion_with_analytes.get('analytes', []))
print('Analyte columns:', analytes_expanded.columns.tolist())
slides_expanded = pd.json_normalize(portion_with_analytes.get('slides', []))
print('Slides columns:', slides_expanded.columns.tolist())
aliquots_with_analytes = analytes_expanded.iloc[0]
aliquots_expanded = pd.json_normalize(aliquots_with_analytes.get('aliquots', []))
print('Aliquots columns:', aliquots_expanded.columns.tolist())

display(samples_expanded.head())
display(portions_expanded.head())
display(analytes_expanded.head())
display(slides_expanded.head())
display(aliquots_expanded.head())


display()
# Out:
# Samples columns: ['tumor_descriptor', 'specimen_type', 'days_to_sample_procurement', 'updated_datetime', 'sample_id', 'submitter_id', 'state', 'preservation_method', 'sample_type', 'tissue_type', 'created_datetime', 'portions', 'pathology_report_uuid', 'days_to_collection', 'initial_weight']
# Portions columns: ['analytes', 'portion_id', 'slides', 'updated_datetime', 'creation_datetime', 'submitter_id', 'weight', 'portion_number', 'state', 'is_ffpe']
# Analyte columns: ['analyte_id', 'experimental_protocol_type', 'aliquots', 'analyte_type', 'updated_datetime', 'normal_tumor_genotype_snp_match', 'spectrophotometer_method', 'submitter_id', 'concentration', 'state', 'a260_a280_ratio']
# Slides columns: ['percent_stromal_cells', 'submitter_id', 'section_location', 'percent_tumor_cells', 'slide_id', 'percent_neutrophil_infiltration', 'percent_lymphocyte_infiltration', 'updated_datetime', 'percent_necrosis', 'percent_monocyte_infiltration', 'percent_normal_cells', 'state', 'percent_tumor_nuclei']
# Aliquots columns: ['aliquot_quantity', 'aliquot_id', 'source_center', 'updated_datetime', 'submitter_id', 'concentration', 'state', 'aliquot_volume', 'center.code', 'center.center_id', 'center.name', 'center.namespace', 'center.short_name', 'center.center_type']
#   tumor_descriptor specimen_type  days_to_sample_procurement  \
# 0          Primary  Solid Tissue                         0.0
# 1          Primary  Solid Tissue                         NaN
# 2   Not Applicable  Solid Tissue                         NaN
#
#                    updated_datetime                             sample_id  \
# 0  2023-11-08T11:17:33.420637-06:00  81ef5a2d-dcb8-49fa-a9ef-c5520d703e18
# 1  2023-11-08T11:10:15.917339-06:00  92058c44-a484-4e08-b1fe-dfe2f03a0aa1
# 2  2023-05-05T14:01:40.186650-05:00  c8e39abb-9027-4636-84b9-7bc03a8d4e49
#
#        submitter_id     state preservation_method          sample_type  \
# 0  TCGA-E2-A1IU-01Z  released                FFPE        Primary Tumor
# 1  TCGA-E2-A1IU-01A  released             Unknown        Primary Tumor
# 2  TCGA-E2-A1IU-11A  released             Unknown  Solid Tissue Normal
#
#   tissue_type                  created_datetime  \
# 0       Tumor  2018-05-17T12:10:31.746556-05:00
# 1       Tumor                               NaN
# 2      Normal                               NaN
#
#                                             portions  \
# 0  [{'analytes': [], 'portion_id': '5458dfd2-8926...
# 1  [{'analytes': [], 'portion_id': '19429156-19ad...
# 2  [{'analytes': [{'analyte_id': 'b60646e4-b524-4...
#
#                   pathology_report_uuid  days_to_collection  initial_weight
# 0                                   NaN                 NaN             NaN
# 1  ACE20EC5-2822-4F50-949E-E194C59F0FCD               136.0           270.0
# 2                                   NaN               136.0           340.0
#                                             analytes  \
# 0  [{'analyte_id': 'b60646e4-b524-4ad7-8cc5-359d5...
#
#                              portion_id  \
# 0  533c254b-0d13-45fb-b9b8-07b4324a45c6
#
#                                               slides  \
# 0  [{'percent_stromal_cells': 10.0, 'submitter_id...
#
#                    updated_datetime  creation_datetime         submitter_id  \
# 0  2018-09-06T13:49:20.245333-05:00       1.300666e+09  TCGA-E2-A1IU-11A-61
#
#    weight portion_number     state is_ffpe
# 0   210.0             61  released   false
#                              analyte_id experimental_protocol_type  \
# 0  b60646e4-b524-4ad7-8cc5-359d598e40db      aDNA Preparation Type
# 1  eec40dee-2d51-4990-809e-12f9edc472c6                    Repli-G
#
#                                             aliquots          analyte_type  \
# 0  [{'aliquot_quantity': 1.95, 'aliquot_id': '296...                   DNA
# 1  [{'aliquot_quantity': 40.0, 'aliquot_id': '3cf...  Repli-G (Qiagen) DNA
#
#                    updated_datetime normal_tumor_genotype_snp_match  \
# 0  2022-04-29T01:58:33.546762-05:00                             Yes
# 1  2022-04-29T01:58:40.400110-05:00                             Yes
#
#   spectrophotometer_method          submitter_id  concentration     state  \
# 0                  UV Spec  TCGA-E2-A1IU-11A-61D           0.15  released
# 1                      NaN  TCGA-E2-A1IU-11A-61W            NaN  released
#
#    a260_a280_ratio
# 0             2.11
# 1              NaN
#    percent_stromal_cells             submitter_id section_location  \
# 0                   10.0  TCGA-E2-A1IU-11A-01-TSA              TOP
# 1                   10.0  TCGA-E2-A1IU-11A-03-TSC              TOP
# 2                    NaN  TCGA-E2-A1IU-11A-05-TSE              TOP
# 3                    NaN  TCGA-E2-A1IU-11A-06-TSF              TOP
# 4                    5.0  TCGA-E2-A1IU-11A-02-TSB              TOP
#
#    percent_tumor_cells                              slide_id  \
# 0                  0.0  1c0aabbc-d315-4571-ada6-4d23b691441e
# 1                  0.0  1e0a5cc1-d90d-4b19-9f96-93f67139fdb7
# 2                  0.0  3bc5b9f2-5fd3-4a00-a8f6-9cf98ab35113
# 3                  0.0  96609ca3-27d5-47b7-a3b2-9f658b24a26b
# 4                  0.0  b1e1d4f0-7a97-4a67-a15f-667ba0454e31
#
#    percent_neutrophil_infiltration  percent_lymphocyte_infiltration  \
# 0                             40.0                             40.0
# 1                             20.0                             20.0
# 2                              0.0                              0.0
# 3                              0.0                              0.0
# 4                             20.0                             20.0
#
#                    updated_datetime  percent_necrosis  \
# 0  2018-09-06T13:49:20.245333-05:00               0.0
# 1  2018-09-06T13:49:20.245333-05:00              10.0
# 2  2018-09-06T13:49:20.245333-05:00               NaN
# 3  2018-09-06T13:49:20.245333-05:00               NaN
# 4  2018-09-06T13:49:20.245333-05:00              15.0
#
#    percent_monocyte_infiltration  percent_normal_cells     state  \
# 0                           10.0                  90.0  released
# 1                           50.0                  80.0  released
# 2                            0.0                 100.0  released
# 3                            0.0                 100.0  released
# 4                           50.0                  80.0  released
#
#    percent_tumor_nuclei
# 0                   0.0
# 1                   0.0
# 2                   NaN
# 3                   NaN
# 4                   0.0
#    aliquot_quantity                            aliquot_id source_center  \
# 0              1.95  29649014-93dc-43a1-921b-7fef21993d35            23
# 1              4.27  48e5f4e0-7f51-47f6-a508-347ed3638a6d            23
# 2              1.00  4b2073cb-62fe-41f3-baa1-200fc865871b            23
#
#                    updated_datetime                  submitter_id  \
# 0  2022-04-29T01:58:34.961222-05:00  TCGA-E2-A1IU-11A-61D-A14E-02
# 1  2022-04-29T01:58:38.593782-05:00  TCGA-E2-A1IU-11A-61D-A14G-09
# 2  2022-04-29T01:58:36.696508-05:00  TCGA-E2-A1IU-11A-61D-A14F-01
#
#    concentration     state  aliquot_volume center.code  \
# 0           0.15  released           13.00          02
# 1           0.08  released           53.40          09
# 2           0.15  released            6.67          01
#
#                        center.center_id  \
# 0  c8611490-4cbd-5651-8de2-64484a515eec
# 1  956ca84c-1124-53ff-824f-fa0c84425425
# 2  5069ce55-a23f-57c4-a28c-70a3c3cb0e4c
#
#                                 center.name  center.namespace  \
# 0                    Harvard Medical School   hms.harvard.edu
# 1  Washington University School of Medicine  genome.wustl.edu
# 2        Broad Institute of MIT and Harvard     broad.mit.edu
#
#   center.short_name center.center_type
# 0               HMS               CGCC
# 1              WUSM                GSC
# 2                BI               CGCC

# %%
expression_index_with_biospecimen = expression_index.merge(biospecimen_metadata_df, on='case_id', how='left',suffixes=('','_biospecimen'))
expression_index_with_biospecimen.head()
# Out:
#                                            file_name  \
# 0  ba295155-272e-43eb-9d6a-e4c9c392e68b.rna_seq.a...
# 1  8d1641ea-7552-4d23-9298-094e0056386a.rna_seq.a...
# 2  2f51534b-248b-4999-bc3f-e42a2e98332e.rna_seq.a...
# 3  b321a3f5-043d-42c6-8c9d-5784d45cb85c.rna_seq.a...
# 4  cafc9e36-c5f0-45df-ad03-16210ff0d870.rna_seq.a...
#
#                               bundle_id  \
# 0  0019c951-16c5-48d0-85c8-58d96b12d330
# 1  0022cd20-f64f-4773-b9ff-a3de0b71b259
# 2  00469928-b243-4cae-acd7-134508e99ceb
# 3  0081f507-b104-4214-9ea1-31dd69130991
# 4  0094f9d0-45ec-4aad-bca0-71c60bdd7113
#
#                                                 path  \
# 0  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 1  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 2  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 3  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 4  /Users/lennonmccartney/Desktop/tcga-brca-multi...
#
#                                        relative_path  \
# 0  0019c951-16c5-48d0-85c8-58d96b12d330/ba295155-...
# 1  0022cd20-f64f-4773-b9ff-a3de0b71b259/8d1641ea-...
# 2  00469928-b243-4cae-acd7-134508e99ceb/2f51534b-...
# 3  0081f507-b104-4214-9ea1-31dd69130991/b321a3f5-...
# 4  0094f9d0-45ec-4aad-bca0-71c60bdd7113/cafc9e36-...
#
#             entity_submitter_id entity_type  \
# 0  TCGA-D8-A1XO-01A-11R-A14M-07     aliquot
# 1  TCGA-AN-A0FN-01A-11R-A034-07     aliquot
# 2  TCGA-AC-A62X-01A-11R-A29R-07     aliquot
# 3  TCGA-E2-A14U-01A-11R-A22K-07     aliquot
# 4  TCGA-E9-A1R3-01A-31R-A14M-07     aliquot
#
#                                 case_id                             entity_id  \
# 0  6a186809-3422-41d0-83d2-867145830936  eddd285e-a946-4e4e-a21d-6e84ed397594
# 1  c2a742fe-3e8b-4210-85a6-7191a1123609  4aac7c40-db6b-4648-a82a-7bf397de913a
# 2  5b2a4f11-ca46-4974-9420-59b4820920bf  cdc523d2-da82-4a3d-a97e-9745c8a802d1
# 3  23b7aaea-1119-4b10-aa1a-0ae255d2f2a6  20d25e27-b509-45eb-a734-9b8d6a40c632
# 4  4922cddc-575c-4b8a-8245-ce5f6876760c  678ba111-3b01-49b7-83d9-165ef0288a34
#
#        access                          submitter_id     data_category  \
# 0  controlled  0e68b49d-a54d-41c3-a5f7-13fc141ab0e8  Sequencing Reads
# 1  controlled  fd4c1bc5-6eab-4830-9178-afbab6a7a954  Sequencing Reads
# 2  controlled  6920521e-f04a-4ae1-b161-df65804500b6  Sequencing Reads
# 3  controlled  f8ed6c74-0202-4ac0-a581-b00c504e9e4b  Sequencing Reads
# 4  controlled  71af5a94-601d-4710-834a-ee8ac0265d20  Sequencing Reads
#
#                                 file_id      data_type experimental_strategy  \
# 0  cb7714fd-20e5-4ecf-9498-591e0c1fdcde  Aligned Reads               RNA-Seq
# 1  786b6363-889b-4437-8830-eac79e5a8d5b  Aligned Reads               RNA-Seq
# 2  2cd40ce3-5054-452e-bd21-854fdcd3646b  Aligned Reads               RNA-Seq
# 3  5d613c10-ab5c-4ab4-a42a-5f68de579ca3  Aligned Reads               RNA-Seq
# 4  bcecf315-bca9-4518-ace3-dad827722905  Aligned Reads               RNA-Seq
#
#   submitter_id_biospecimen                                            samples  \
# 0             TCGA-D8-A1XO  [{'tumor_descriptor': 'Primary', 'specimen_typ...
# 1             TCGA-AN-A0FN  [{'tumor_descriptor': 'Primary', 'sample_id': ...
# 2             TCGA-AC-A62X  [{'tumor_descriptor': 'Primary', 'specimen_typ...
# 3             TCGA-E2-A14U  [{'tumor_descriptor': 'Primary', 'sample_id': ...
# 4             TCGA-E9-A1R3  [{'tumor_descriptor': 'Not Applicable', 'speci...
#
#   project.project_id
# 0          TCGA-BRCA
# 1          TCGA-BRCA
# 2          TCGA-BRCA
# 3          TCGA-BRCA
# 4          TCGA-BRCA

# %% [markdown]
# ## Helper to read a single expression table
#
# We only need the `gene_id` column plus a quantitative abundance metric (`tpm_unstranded`). The helper below returns one `pd.Series` per sample and removes the technical summary rows (the `N_*` counters at the top of each file).

# %%
from pathlib import Path


def read_expression_table(path: Path, value_column: str = "unstranded") -> pd.Series:
    '''Load one RNA-seq table and return the chosen value column indexed by gene ID.'''

    usecols = ["gene_id", value_column]
    df = pd.read_csv(
        path,
        sep="\t",
        comment="#",
        usecols=usecols,
        dtype={value_column: "float32"},
    ).dropna(subset=["gene_id"])
    series = df.set_index("gene_id")[value_column]
    series = series[~series.index.str.startswith("N_")]
    series.name = path.name.split(".")[0]
    return series


# Quick sanity check on the first file
first_sample = read_expression_table(Path(expression_index.loc[0, "path"]))
first_sample.head()
# Out:
# gene_id
# ENSG00000000003.15    4370.0
# ENSG00000000005.6        7.0
# ENSG00000000419.13    2625.0
# ENSG00000000457.14    3005.0
# ENSG00000000460.17    1578.0
# Name: ba295155-272e-43eb-9d6a-e4c9c392e68b, dtype: float32

# %% [markdown]
# ## Build the combined expression matrix
#
# We iterate through every discovered file, ensure the genes line up across samples, and concatenate the resulting vectors column-wise. Progress messages every 100 samples make it easier to monitor long runs.

# %%
from typing import Optional

expression_series: list[pd.Series] = []
gene_index: Optional[pd.Index] = None

total_files = len(expression_index)
for idx, path in enumerate(expression_index["path"], start=1):
    series = read_expression_table(Path(path))
    if gene_index is None:
        gene_index = series.index
    elif not series.index.equals(gene_index):
        # Align to the reference order if a file arrives with an unexpected layout.
        series = series.reindex(gene_index)
    expression_series.append(series)
    if idx % 100 == 0 or idx == total_files:
        print(f"Loaded {idx}/{total_files} samples")

expression_matrix = pd.concat(expression_series, axis=1)
expression_matrix.head()
# Out:
# Loaded 100/1197 samples
# Loaded 200/1197 samples
# Loaded 300/1197 samples
# Loaded 400/1197 samples
# Loaded 500/1197 samples
# Loaded 600/1197 samples
# Loaded 700/1197 samples
# Loaded 800/1197 samples
# Loaded 900/1197 samples
# Loaded 1000/1197 samples
# Loaded 1100/1197 samples
# Loaded 1197/1197 samples
#                     ba295155-272e-43eb-9d6a-e4c9c392e68b  \
# gene_id
# ENSG00000000003.15                                4370.0
# ENSG00000000005.6                                    7.0
# ENSG00000000419.13                                2625.0
# ENSG00000000457.14                                3005.0
# ENSG00000000460.17                                1578.0
#
#                     8d1641ea-7552-4d23-9298-094e0056386a  \
# gene_id
# ENSG00000000003.15                                2443.0
# ENSG00000000005.6                                  144.0
# ENSG00000000419.13                                2322.0
# ENSG00000000457.14                                1466.0
# ENSG00000000460.17                                 409.0
#
#                     2f51534b-248b-4999-bc3f-e42a2e98332e  \
# gene_id
# ENSG00000000003.15                                3508.0
# ENSG00000000005.6                                    7.0
# ENSG00000000419.13                                2421.0
# ENSG00000000457.14                                 839.0
# ENSG00000000460.17                                 744.0
#
#                     b321a3f5-043d-42c6-8c9d-5784d45cb85c  \
# gene_id
# ENSG00000000003.15                                6928.0
# ENSG00000000005.6                                   17.0
# ENSG00000000419.13                                1812.0
# ENSG00000000457.14                                1651.0
# ENSG00000000460.17                                 366.0
#
#                     cafc9e36-c5f0-45df-ad03-16210ff0d870  \
# gene_id
# ENSG00000000003.15                                2890.0
# ENSG00000000005.6                                    4.0
# ENSG00000000419.13                                4025.0
# ENSG00000000457.14                                2769.0
# ENSG00000000460.17                                 663.0
#
#                     c763a483-415e-4cb4-9cdf-4e6c31e8a9c9  \
# gene_id
# ENSG00000000003.15                                1635.0
# ENSG00000000005.6                                  101.0
# ENSG00000000419.13                                1565.0
# ENSG00000000457.14                                1183.0
# ENSG00000000460.17                                 419.0
#
#                     7135f14b-e84f-4ebf-8d95-b2a3c843fd4d  \
# gene_id
# ENSG00000000003.15                                3456.0
# ENSG00000000005.6                                   22.0
# ENSG00000000419.13                                1779.0
# ENSG00000000457.14                                2176.0
# ENSG00000000460.17                                 864.0
#
#                     5fd42405-ebfe-4210-bc2f-d8310e3e14ee  \
# gene_id
# ENSG00000000003.15                                1410.0
# ENSG00000000005.6                                   14.0
# ENSG00000000419.13                                1431.0
# ENSG00000000457.14                                1556.0
# ENSG00000000460.17                                 318.0
#
#                     9ccd787f-fde1-4fe6-a11f-d6203eaf9faf  \
# gene_id
# ENSG00000000003.15                                1899.0
# ENSG00000000005.6                                    4.0
# ENSG00000000419.13                                2167.0
# ENSG00000000457.14                                1516.0
# ENSG00000000460.17                                 417.0
#
#                     4a88d54f-c88c-4ffd-84c9-069b53f2cb28  ...  \
# gene_id                                                   ...
# ENSG00000000003.15                                3362.0  ...
# ENSG00000000005.6                                   35.0  ...
# ENSG00000000419.13                                3346.0  ...
# ENSG00000000457.14                                2135.0  ...
# ENSG00000000460.17                                 973.0  ...
#
#                     ca9d1ab5-ea78-46f4-9225-8147639d013c  \
# gene_id
# ENSG00000000003.15                                4518.0
# ENSG00000000005.6                                   10.0
# ENSG00000000419.13                                1657.0
# ENSG00000000457.14                                2009.0
# ENSG00000000460.17                                 739.0
#
#                     97a50d88-e662-43d5-9cef-2915545e8968  \
# gene_id
# ENSG00000000003.15                                3958.0
# ENSG00000000005.6                                   18.0
# ENSG00000000419.13                                2113.0
# ENSG00000000457.14                                1830.0
# ENSG00000000460.17                                 931.0
#
#                     8a27980e-a506-4cb3-91f2-3f0e5a19acfe  \
# gene_id
# ENSG00000000003.15                                5469.0
# ENSG00000000005.6                                    9.0
# ENSG00000000419.13                                2153.0
# ENSG00000000457.14                                 985.0
# ENSG00000000460.17                                1452.0
#
#                     fe00aecb-7b06-4e76-b999-99ee41ad20ea  \
# gene_id
# ENSG00000000003.15                                2212.0
# ENSG00000000005.6                                    0.0
# ENSG00000000419.13                                1184.0
# ENSG00000000457.14                                1426.0
# ENSG00000000460.17                                 343.0
#
#                     2c1b1cbb-6e9f-4416-8faa-abb31d6b4e0e  \
# gene_id
# ENSG00000000003.15                                3321.0
# ENSG00000000005.6                                    0.0
# ENSG00000000419.13                                3880.0
# ENSG00000000457.14                                1559.0
# ENSG00000000460.17                                 880.0
#
#                     967f7008-e212-4114-ab43-dc2a6295f80c  \
# gene_id
# ENSG00000000003.15                                2586.0
# ENSG00000000005.6                                  286.0
# ENSG00000000419.13                                1655.0
# ENSG00000000457.14                                1723.0
# ENSG00000000460.17                                 600.0
#
#                     deb7967f-9339-4bb1-ae0b-81a72a472bba  \
# gene_id
# ENSG00000000003.15                                2127.0
# ENSG00000000005.6                                    0.0
# ENSG00000000419.13                                 742.0
# ENSG00000000457.14                                 911.0
# ENSG00000000460.17                                 328.0
#
#                     574d0a5f-8cb7-4783-8d5e-b07c1b3460dc  \
# gene_id
# ENSG00000000003.15                                8020.0
# ENSG00000000005.6                                22722.0
# ENSG00000000419.13                                1676.0
# ENSG00000000457.14                                1065.0
# ENSG00000000460.17                                 918.0
#
#                     64b12ba7-a481-4fdb-9c74-38c94c7ef3c9  \
# gene_id
# ENSG00000000003.15                                1417.0
# ENSG00000000005.6                                    2.0
# ENSG00000000419.13                                1138.0
# ENSG00000000457.14                                 904.0
# ENSG00000000460.17                                 233.0
#
#                     74179e5e-2d3c-417e-8844-6740ea9fb2e5
# gene_id
# ENSG00000000003.15                                4263.0
# ENSG00000000005.6                                    9.0
# ENSG00000000419.13                                2071.0
# ENSG00000000457.14                                1101.0
# ENSG00000000460.17                                 717.0
#
# [5 rows x 1197 columns]

# %%
print(f"Expression matrix shape: {expression_matrix.shape}")
expression_matrix.iloc[:5, :5]
# Out:
# Expression matrix shape: (60660, 1197)
#                     ba295155-272e-43eb-9d6a-e4c9c392e68b  \
# gene_id
# ENSG00000000003.15                                4370.0
# ENSG00000000005.6                                    7.0
# ENSG00000000419.13                                2625.0
# ENSG00000000457.14                                3005.0
# ENSG00000000460.17                                1578.0
#
#                     8d1641ea-7552-4d23-9298-094e0056386a  \
# gene_id
# ENSG00000000003.15                                2443.0
# ENSG00000000005.6                                  144.0
# ENSG00000000419.13                                2322.0
# ENSG00000000457.14                                1466.0
# ENSG00000000460.17                                 409.0
#
#                     2f51534b-248b-4999-bc3f-e42a2e98332e  \
# gene_id
# ENSG00000000003.15                                3508.0
# ENSG00000000005.6                                    7.0
# ENSG00000000419.13                                2421.0
# ENSG00000000457.14                                 839.0
# ENSG00000000460.17                                 744.0
#
#                     b321a3f5-043d-42c6-8c9d-5784d45cb85c  \
# gene_id
# ENSG00000000003.15                                6928.0
# ENSG00000000005.6                                   17.0
# ENSG00000000419.13                                1812.0
# ENSG00000000457.14                                1651.0
# ENSG00000000460.17                                 366.0
#
#                     cafc9e36-c5f0-45df-ad03-16210ff0d870
# gene_id
# ENSG00000000003.15                                2890.0
# ENSG00000000005.6                                    4.0
# ENSG00000000419.13                                4025.0
# ENSG00000000457.14                                2769.0
# ENSG00000000460.17                                 663.0

# %% [markdown]
# ## Persist processed outputs
#
# The TPM matrix is saved as a gzipped TSV to keep downstream tooling simple. A companion manifest captures where each column originated and the original file sizes.

# %%
expression_output_path = PROCESSED_DATA_DIR / "tcga_brca_expression_tpm.tsv.gz"
manifest_output_path = PROCESSED_DATA_DIR / "expression_file_index.tsv"

expression_matrix.to_csv(expression_output_path, sep="	", compression="gzip")

manifest_df = expression_index.copy()
manifest_df["file_size_mb"] = manifest_df["path"].map(lambda p: round(p.stat().st_size / 1024 ** 2, 3))
manifest_df = manifest_df.drop(columns=["path"])
manifest_df.to_csv(manifest_output_path, sep="	", index=False)

expression_output_path, manifest_output_path
# Out:
# (PosixPath('/Users/lennonmccartney/Desktop/tcga-brca-multiomics-subtyping/data/processed/tcga_brca_expression_tpm.tsv.gz'),
#  PosixPath('/Users/lennonmccartney/Desktop/tcga-brca-multiomics-subtyping/data/processed/expression_file_index.tsv'))

# %% [markdown]
# ## Quick summary statistics
#
# Verify the number of samples/genes and inspect the distribution of file sizes to catch obvious anomalies.

# %%
summary = pd.Series(
    {
        "n_samples": expression_matrix.shape[1],
        "n_genes": expression_matrix.shape[0],
        "min_file_size_mb": expression_index["path"].map(lambda p: p.stat().st_size / 1024 ** 2).min(),
        "max_file_size_mb": expression_index["path"].map(lambda p: p.stat().st_size / 1024 ** 2).max(),
    }
)
summary
# Out:
# n_samples            1197.000000
# n_genes             60660.000000
# min_file_size_mb        4.007236
# max_file_size_mb        4.075985
# dtype: float64

# %% [markdown]
# ## Inspect clinical XML files
#
# Review the clinical, biospecimen, and SSF XML bundles to understand their structure before parsing them downstream.

# %%
from pathlib import Path

def collect_clinical_xml(root: Path) -> pd.DataFrame:
    records: list[dict[str, object]] = []
    if not root.exists():
        raise FileNotFoundError(f'Clinical directory not found: {root}')
    bundle_dirs = sorted(p for p in root.iterdir() if p.is_dir())
    for bundle in bundle_dirs:
        for xml_path in sorted(bundle.glob('*.xml')):
            filename = xml_path.name
            parts = filename.split('.')
            case_id = parts[-2] if len(parts) >= 2 else filename
            file_type = parts[1] if len(parts) >= 3 else 'unknown'
            records.append(
                {
                    'bundle_id': bundle.name,
                    'case_id': case_id,
                    'file_type': file_type,
                    'file_name': filename,
                    'relative_path': xml_path.relative_to(root).as_posix(),
                    'path': str(xml_path),
                }
            )
    if not records:
        raise FileNotFoundError(f'No XML files discovered under {root}')
    return pd.DataFrame.from_records(records)

clinical_index = collect_clinical_xml(CLINICAL_DATA_DIR)
bundle_count = clinical_index['bundle_id'].nunique()
print(f'Discovered {len(clinical_index)} XML files across {bundle_count} bundles.')
clinical_index.head()
# Out:
# Discovered 3369 XML files across 3369 bundles.
#                               bundle_id       case_id        file_type  \
# 0  00049989-fa21-48fb-8dda-710c0dd5932e  TCGA-A2-A0CT     org_clinical
# 1  0026e7b3-6e38-44cb-83cb-6618a7681f0a  TCGA-A7-A0DA  org_biospecimen
# 2  002ce63d-8c5d-4dcc-b919-ed5dbeb0be55  TCGA-BH-A0BD          org_ssf
# 3  004b6bd4-19d0-4b40-99ef-1a76313fe7a5  TCGA-GM-A2DD     org_clinical
# 4  00a012e7-e97f-4fea-9402-37ac734217ca  TCGA-B6-A1KC  org_biospecimen
#
#                                            file_name  \
# 0  nationwidechildrens.org_clinical.TCGA-A2-A0CT.xml
# 1  nationwidechildrens.org_biospecimen.TCGA-A7-A0...
# 2       nationwidechildrens.org_ssf.TCGA-BH-A0BD.xml
# 3  nationwidechildrens.org_clinical.TCGA-GM-A2DD.xml
# 4  nationwidechildrens.org_biospecimen.TCGA-B6-A1...
#
#                                        relative_path  \
# 0  00049989-fa21-48fb-8dda-710c0dd5932e/nationwid...
# 1  0026e7b3-6e38-44cb-83cb-6618a7681f0a/nationwid...
# 2  002ce63d-8c5d-4dcc-b919-ed5dbeb0be55/nationwid...
# 3  004b6bd4-19d0-4b40-99ef-1a76313fe7a5/nationwid...
# 4  00a012e7-e97f-4fea-9402-37ac734217ca/nationwid...
#
#                                                 path
# 0  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 1  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 2  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 3  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 4  /Users/lennonmccartney/Desktop/tcga-brca-multi...

# %%
## check if case id has any duplicates
clinical_index['case_id'].value_counts().sort_values(ascending=False)
# Out:
# case_id
# TCGA-W8-A86G    4
# TCGA-A8-A07E    4
# TCGA-5L-AAT1    4
# TCGA-AO-A1KT    4
# TCGA-LL-A440    4
#                ..
# TCGA-D8-A73X    3
# TCGA-E2-A15G    3
# TCGA-A2-A0D2    3
# TCGA-A2-A0CK    3
# TCGA-BH-A0B2    1
# Name: count, Length: 1098, dtype: int64

# %%
import xml.etree.ElementTree as ET

if clinical_index.empty:
    raise ValueError('Clinical XML index is empty; nothing to inspect.')
sample_xml_path = Path(clinical_index.loc[0, 'path'])
tree = ET.parse(sample_xml_path)
root = tree.getroot()

print(f'Previewing XML file: {sample_xml_path.name}')
print(f'Root tag: {root.tag}')
for element in list(root)[:5]:
    tag = element.tag.split('}')[-1]
    text = (element.text or '').strip().replace('', ' ')
    snippet = text[:80] + ('…' if len(text) > 80 else '')
    print(f'- {tag}: {snippet}')
    sub_elements = list(element)[:3]
    for child in sub_elements:
        child_tag = child.tag.split('}')[-1]
        child_text = (child.text or '').strip().replace('', ' ')
        child_snippet = child_text[:80] + ('…' if len(child_text) > 80 else '')
        print(f'    · {child_tag}: {child_snippet}')
    if sub_elements:
        print('')
# Out:
# Previewing XML file: nationwidechildrens.org_clinical.TCGA-A2-A0CT.xml
# Root tag: {http://tcga.nci/bcr/xml/clinical/brca/2.7}tcga_bcr
# - admin:
#     · bcr:  N a t i o n w i d e   C h i l d r e n ' s   H o s p i t a l
#     · file_uuid:  1 7 2 B 8 2 5 D - 7 A 5 C - 4 5 4 1 - 8 1 9 0 - 3 3 2 0 7 A F 4 7 4 F 9
#     · batch_number:  6 1 . 8 9 . 0
#
# - patient:
#     · additional_studies:
#     · tumor_tissue_site:  B r e a s t
#     · tumor_tissue_site_other:

# %%
from collections import Counter

def element_text_map(element):
    data: dict[str, str] = {}
    for child in element:
        text = (child.text or '').strip()
        if not text:
            continue
        tag = child.tag.split('}')[-1]
        data[tag] = text
    return data

sample_xml_path = Path(clinical_index.loc[0, 'path'])
tree = ET.parse(sample_xml_path)
root = tree.getroot()

patient_elem = root.find('.//{*}patient')
patient_series = pd.Series(element_text_map(patient_elem), name='patient')

drug_rows = [element_text_map(node) for node in root.findall('.//{*}drug')]
drug_df = pd.DataFrame(drug_rows)

followup_rows = [element_text_map(node) for node in root.findall('.//{*}follow_up')]
followup_df = pd.DataFrame(followup_rows)

uniq_tags = Counter(elem.tag.split('}')[-1] for elem in root.iter())

print(f'Sample XML: {sample_xml_path.name}')
print(f'Patient fields captured: {patient_series.shape[0]}')
display(patient_series.sort_index())

print(f'Drug records: {len(drug_df)}')
display(drug_df)

print(f'Follow-up records: {len(followup_df)}')
display(followup_df)

print(f'Unique XML tags in file: {len(uniq_tags)}')
pd.Series(uniq_tags).sort_values(ascending=False).head(15)
# Out:
# Sample XML: nationwidechildrens.org_clinical.TCGA-A2-A0CT.xml
# Patient fields captured: 44
# age_at_initial_pathologic_diagnosis                                                                                          71
# axillary_lymph_node_stage_method_type                                                                Sentinel node biopsy alone
# bcr_patient_barcode                                                                                                TCGA-A2-A0CT
# bcr_patient_uuid                                                                           378778d2-b331-4867-a93b-c64028c8b4c7
# breast_carcinoma_estrogen_receptor_status                                                                              Positive
# breast_carcinoma_immunohistochemistry_pos_cell_score                                                                          0
# breast_carcinoma_progesterone_receptor_status                                                                          Negative
# breast_carcinoma_surgical_procedure_name                                                                      Simple Mastectomy
# cytokeratin_immunohistochemistry_staining_method_micrometastasis_indicator                                                  YES
# day_of_form_completion                                                                                                        9
# days_to_birth                                                                                                            -25959
# days_to_initial_pathologic_diagnosis                                                                                          0
# days_to_last_followup                                                                                                      1918
# er_level_cell_percentage_category                                                                                        90-99%
# ethnicity                                                                                                NOT HISPANIC OR LATINO
# gender                                                                                                                   FEMALE
# her2_immunohistochemistry_level_result                                                                                       2+
# her2_neu_chromosone_17_signal_ratio_value                                                                                   1.3
# histological_type                                                                                 Infiltrating Ductal Carcinoma
# history_of_neoadjuvant_treatment                                                                                             No
# icd_10                                                                                                                    C50.9
# icd_o_3_histology                                                                                                        8500/3
# icd_o_3_site                                                                                                              C50.9
# informed_consent_verified                                                                                                   YES
# initial_pathologic_diagnosis_method                                                                          Core needle biopsy
# lab_proc_her2_neu_immunohistochemistry_receptor_status                                                                Equivocal
# lab_procedure_her2_neu_in_situ_hybrid_outcome_type                                                                     Negative
# lymph_node_examined_count                                                                                                     2
# margin_status                                                                                                          Negative
# menopause_status                                                              Post (prior bilateral ovariectomy OR >12 mo si...
# month_of_form_completion                                                                                                      9
# number_of_lymphnodes_positive_by_he                                                                                           0
# number_of_lymphnodes_positive_by_ihc                                                                                          0
# other_dx                                                                                                                     No
# patient_id                                                                                                                 A0CT
# person_neoplasm_cancer_status                                                                                        TUMOR FREE
# progesterone_receptor_level_cell_percent_category                                                                          <10%
# tissue_prospective_collection_indicator                                                                                      NO
# tissue_retrospective_collection_indicator                                                                                   YES
# tissue_source_site                                                                                                           A2
# tumor_tissue_site                                                                                                        Breast
# vital_status                                                                                                              Alive
# year_of_form_completion                                                                                                    2010
# year_of_initial_pathologic_diagnosis                                                                                       2005
# Name: patient, dtype: object
# Drug records: 4
#   regimen_number    bcr_drug_barcode                         bcr_drug_uuid  \
# 0              4  TCGA-A2-A0CT-D1976  fe69a660-e936-4a3f-8e5d-8cbfbb6dfeb4
# 1              2  TCGA-A2-A0CT-D1974  76a54d5e-e978-4768-b8d6-d25277ef9803
# 2              3  TCGA-A2-A0CT-D1975  b6f4f507-e6ee-45bc-b50b-d9a2bb53bcaa
# 3              1  TCGA-A2-A0CT-D1973  46d7f184-146c-4978-a041-32b27f642b48
#
#   prescribed_dose prescribed_dose_units days_to_drug_therapy_start  \
# 0              20                mg/day                        559
# 1             900                    mg                         75
# 2               1                    mg                        160
# 3              90                    mg                         75
#
#   days_to_drug_therapy_end   drug_name regimen_indication therapy_ongoing  \
# 0                     1537   Tamoxifen           ADJUVANT              NO
# 1                      138     Cytoxan           ADJUVANT              NO
# 2                      433    Arimidex           ADJUVANT              NO
# 3                      138  Adriamycin           ADJUVANT              NO
#
#   day_of_form_completion month_of_form_completion year_of_form_completion  \
# 0                      9                        9                    2010
# 1                      9                        9                    2010
# 2                      9                        9                    2010
# 3                      9                        9                    2010
#
#   total_dose total_dose_units number_cycles
# 0        NaN              NaN           NaN
# 1       3600               mg             4
# 2        NaN              NaN           NaN
# 3        360               mg             4
# Follow-up records: 1
#   bcr_followup_barcode                     bcr_followup_uuid  \
# 0  TCGA-A2-A0CT-F13730  E5069DEC-D655-42B1-81A6-4F008FC9EF78
#
#   followup_case_report_form_submission_reason radiation_therapy  \
# 0              Scheduled Follow-up Submission                NO
#
#   postoperative_rx_tx vital_status days_to_last_followup  \
# 0                 YES        Alive                  2289
#
#   person_neoplasm_cancer_status new_tumor_event_after_initial_treatment  \
# 0                    TUMOR FREE                                      NO
#
#   day_of_form_completion month_of_form_completion year_of_form_completion
# 0                      9                        6                    2011
# Unique XML tags in file: 187
# day_of_form_completion        6
# year_of_form_completion       6
# month_of_form_completion      6
# days_to_drug_therapy_start    4
# drug                          4
# tx_on_clinical_trial          4
# regimen_number                4
# bcr_drug_barcode              4
# bcr_drug_uuid                 4
# total_dose                    4
# total_dose_units              4
# prescribed_dose_units         4
# number_cycles                 4
# prescribed_dose               4
# days_to_drug_therapy_end      4
# dtype: int64

# %% [markdown]
# ## Inspect biospecimen XML files
#
# Biospecimen files capture sample-level metadata (sample barcodes, aliquots, and vial identifiers) that map directly to the expression matrix columns.

# %%
def collect_biospecimen_xml(root: Path) -> pd.DataFrame:
    records: list[dict[str, object]] = []
    for bundle in sorted(p for p in root.iterdir() if p.is_dir()):
        for xml_path in sorted(bundle.glob('*.xml')):
            if 'biospecimen' not in xml_path.name.lower():
                continue
            filename = xml_path.name
            case_id = filename.split('.')[-2]
            records.append(
                {
                    'bundle_id': bundle.name,
                    'case_id': case_id,
                    'file_name': filename,
                    'relative_path': xml_path.relative_to(CLINICAL_DATA_DIR).as_posix(),
                    'path': str(xml_path),
                }
            )
    if not records:
        raise FileNotFoundError('No biospecimen XML files discovered')
    return pd.DataFrame.from_records(records)

biospecimen_index = collect_biospecimen_xml(CLINICAL_DATA_DIR)
print(f'Discovered {len(biospecimen_index)} biospecimen XML files.')
biospecimen_index.head()
# Out:
# Discovered 1098 biospecimen XML files.
#                               bundle_id       case_id  \
# 0  0026e7b3-6e38-44cb-83cb-6618a7681f0a  TCGA-A7-A0DA
# 1  00a012e7-e97f-4fea-9402-37ac734217ca  TCGA-B6-A1KC
# 2  00d770a2-3013-40b6-acf9-5b2d1f11caad  TCGA-GM-A2DO
# 3  01318ff3-7bfb-49cf-9427-16914cadb09e  TCGA-AC-A2QH
# 4  015bb72b-c035-4274-8318-b0f4020a3a1e  TCGA-AR-A0U0
#
#                                            file_name  \
# 0  nationwidechildrens.org_biospecimen.TCGA-A7-A0...
# 1  nationwidechildrens.org_biospecimen.TCGA-B6-A1...
# 2  nationwidechildrens.org_biospecimen.TCGA-GM-A2...
# 3  nationwidechildrens.org_biospecimen.TCGA-AC-A2...
# 4  nationwidechildrens.org_biospecimen.TCGA-AR-A0...
#
#                                        relative_path  \
# 0  0026e7b3-6e38-44cb-83cb-6618a7681f0a/nationwid...
# 1  00a012e7-e97f-4fea-9402-37ac734217ca/nationwid...
# 2  00d770a2-3013-40b6-acf9-5b2d1f11caad/nationwid...
# 3  01318ff3-7bfb-49cf-9427-16914cadb09e/nationwid...
# 4  015bb72b-c035-4274-8318-b0f4020a3a1e/nationwid...
#
#                                                 path
# 0  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 1  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 2  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 3  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 4  /Users/lennonmccartney/Desktop/tcga-brca-multi...

# %%
## check if case id has any duplicates
biospecimen_index['case_id'].value_counts().sort_values(ascending=False)
# Out:
# case_id
# TCGA-A7-A0DA    1
# TCGA-A2-A0D4    1
# TCGA-AR-A24Q    1
# TCGA-A7-A4SB    1
# TCGA-BH-A0B1    1
#                ..
# TCGA-C8-A275    1
# TCGA-A7-A2KD    1
# TCGA-BH-A0BM    1
# TCGA-E2-A14W    1
# TCGA-AO-A126    1
# Name: count, Length: 1098, dtype: int64

# %%
def parse_biospecimen(path: Path) -> dict[str, pd.DataFrame]:
    tree = ET.parse(path)
    root = tree.getroot()
    def map_children(element):
        row = {}
        for child in element:
            text = (child.text or '').strip()
            if not text:
                continue
            tag = child.tag.split('}')[-1]
            row[tag] = text
        return row
    patient = root.find('.//{*}patient')
    patient_df = pd.DataFrame([map_children(patient)]) if patient is not None else pd.DataFrame()
    samples = [map_children(sample) for sample in root.findall('.//{*}samples//{*}sample')]
    portions = [map_children(portion) for portion in root.findall('.//{*}portions//{*}portion')]
    aliquots = [map_children(aliquot) for aliquot in root.findall('.//{*}aliquots//{*}aliquot')]
    return {
        'patient': patient_df,
        'samples': pd.DataFrame(samples),
        'portions': pd.DataFrame(portions),
        'aliquots': pd.DataFrame(aliquots),
    }

biospecimen_path = Path(biospecimen_index.loc[0, 'path'])
biospecimen_tables = parse_biospecimen(biospecimen_path)
print(f'Sample biospecimen file: {biospecimen_path.name}')
for table_name, df in biospecimen_tables.items():
    print(f"{table_name.title()} rows: {len(df)}")
    if not df.empty:
        display(df.head())

sample_barcodes = biospecimen_tables['samples'].get('bcr_sample_barcode')
if sample_barcodes is not None:
    print('Example sample barcodes:')
    print(sample_barcodes[:5])
# Out:
# Sample biospecimen file: nationwidechildrens.org_biospecimen.TCGA-A7-A0DA.xml
# Patient rows: 1
#   bcr_patient_barcode                      bcr_patient_uuid  \
# 0        TCGA-A7-A0DA  3afa1e93-1df8-4e4c-aaa4-557463f4bb77
#
#   tissue_source_site patient_id days_to_index
# 0                 A7       A0DA             0
# Samples rows: 2
#   sample_type_id vial_number           sample_type initial_weight  \
# 0             01           A         Primary Tumor            350
# 1             10           A  Blood Derived Normal            NaN
#
#   oct_embedded days_to_collection bcr_sample_barcode  \
# 0        false                177   TCGA-A7-A0DA-01A
# 1        false                177   TCGA-A7-A0DA-10A
#
#                         bcr_sample_uuid is_ffpe  \
# 0  4f441e61-6bea-4a12-841d-def270804bbe      NO
# 1  bb28c682-0071-4642-bab6-768b0fc322c6      NO
#
#                   pathology_report_uuid  \
# 0  69AC5937-3FFD-40FB-9922-79DB3CED7510
# 1                                   NaN
#
#                           pathology_report_file_name
# 0  TCGA-A7-A0DA.69AC5937-3FFD-40FB-9922-79DB3CED7...
# 1                                                NaN
# Portions rows: 2
#   portion_number portion_sequence day_of_creation month_of_creation  \
# 0             31                3              14                12
# 1             01                1              14                05
#
#   year_of_creation weight  bcr_portion_barcode  \
# 0             2010  30.00  TCGA-A7-A0DA-01A-31
# 1             2010    NaN  TCGA-A7-A0DA-10A-01
#
#                        bcr_portion_uuid is_ffpe
# 0  51866cc5-8c50-41fa-a490-f23b3adb541d      NO
# 1  dba0ceee-ecdd-4b46-b79c-0bed0553933d      NO
# Aliquots rows: 11
#   plate_id center_id day_of_shipment month_of_shipment year_of_shipment  \
# 0     A10X        02              12                01             2011
# 1     A10Y        09              12                01             2011
# 2     A111        01              12                01             2011
# 3     A112        05              12                01             2011
# 4     A114        13              12                01             2011
#
#             bcr_aliquot_barcode                      bcr_aliquot_uuid  \
# 0  TCGA-A7-A0DA-01A-31D-A10X-02  013b8901-2f00-46f4-b864-0a5e7d4efa6c
# 1  TCGA-A7-A0DA-01A-31D-A10Y-09  878337fe-9f41-44f5-9760-3977e7d75308
# 2  TCGA-A7-A0DA-01A-31D-A111-01  91c8c373-e923-4e7f-b8b3-2417e92760c7
# 3  TCGA-A7-A0DA-01A-31D-A112-05  dd1d7840-21e5-4eb8-9795-91d0659cf8d9
# 4  TCGA-A7-A0DA-01A-31R-A114-13  c8638f56-52c7-4aab-9a57-f2318f44df97
#
#   concentration quantity volume plate_row plate_column  \
# 0          0.15     1.95  13.00         D            3
# 1          0.08     2.08  26.00         D            3
# 2          0.15     1.00   6.67         D            3
# 3          0.15     4.01  26.70         D            3
# 4          0.15     3.00  20.00         G            3
#
#   biospecimen_barcode_bottom source_center is_derived_from_ffpe
# 0                 0100490585            23                   NO
# 1                 0100490489            23                   NO
# 2                 0100487609            23                   NO
# 3                 0100488857            23                   NO
# 4                 0099014268            23                   NO
# Example sample barcodes:
# 0    TCGA-A7-A0DA-01A
# 1    TCGA-A7-A0DA-10A
# Name: bcr_sample_barcode, dtype: object

# %% [markdown]
# ## Inspect SSF XML files
#
# Site-specific factor (SSF) files summarize additional pathologic measurements for each case. Parse one to understand the available fields.

# %%
def collect_ssf_xml(root: Path) -> pd.DataFrame:
    records: list[dict[str, object]] = []
    for bundle in sorted(p for p in root.iterdir() if p.is_dir()):
        for xml_path in sorted(bundle.glob('*.xml')):
            if 'ssf' not in xml_path.name.lower():
                continue
            filename = xml_path.name
            case_id = filename.split('.')[-2]
            records.append(
                {
                    'bundle_id': bundle.name,
                    'case_id': case_id,
                    'file_name': filename,
                    'relative_path': xml_path.relative_to(CLINICAL_DATA_DIR).as_posix(),
                    'path': str(xml_path),
                }
            )
    if not records:
        raise FileNotFoundError('No SSF XML files discovered')
    return pd.DataFrame.from_records(records)

ssf_index = collect_ssf_xml(CLINICAL_DATA_DIR)
print(f'Discovered {len(ssf_index)} SSF XML files.')
ssf_index.head()
# Out:
# Discovered 1097 SSF XML files.
#                               bundle_id       case_id  \
# 0  002ce63d-8c5d-4dcc-b919-ed5dbeb0be55  TCGA-BH-A0BD
# 1  00a19cf8-7c4d-4fc8-8919-709454bebaf7  TCGA-A8-A07I
# 2  00d12d5e-af74-4078-94e0-312e5b0b224e  TCGA-PL-A8LV
# 3  01078de8-87d5-4e09-97b6-4c65d9c52a11  TCGA-C8-A274
# 4  011b4145-c839-4e70-803f-8c2045828d27  TCGA-BH-A0C0
#
#                                       file_name  \
# 0  nationwidechildrens.org_ssf.TCGA-BH-A0BD.xml
# 1  nationwidechildrens.org_ssf.TCGA-A8-A07I.xml
# 2  nationwidechildrens.org_ssf.TCGA-PL-A8LV.xml
# 3  nationwidechildrens.org_ssf.TCGA-C8-A274.xml
# 4  nationwidechildrens.org_ssf.TCGA-BH-A0C0.xml
#
#                                        relative_path  \
# 0  002ce63d-8c5d-4dcc-b919-ed5dbeb0be55/nationwid...
# 1  00a19cf8-7c4d-4fc8-8919-709454bebaf7/nationwid...
# 2  00d12d5e-af74-4078-94e0-312e5b0b224e/nationwid...
# 3  01078de8-87d5-4e09-97b6-4c65d9c52a11/nationwid...
# 4  011b4145-c839-4e70-803f-8c2045828d27/nationwid...
#
#                                                 path
# 0  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 1  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 2  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 3  /Users/lennonmccartney/Desktop/tcga-brca-multi...
# 4  /Users/lennonmccartney/Desktop/tcga-brca-multi...

# %%
## check if case id has any duplicates
ssf_index['case_id'].value_counts().sort_values(ascending=False)
# Out:
# case_id
# TCGA-BH-A0BD    1
# TCGA-AC-A62V    1
# TCGA-BH-A18L    1
# TCGA-AC-A8OP    1
# TCGA-AO-A1KQ    1
#                ..
# TCGA-A8-A06Y    1
# TCGA-BH-A1ET    1
# TCGA-AC-A3TN    1
# TCGA-A2-A4RY    1
# TCGA-BH-A1FR    1
# Name: count, Length: 1097, dtype: int64

# %%
def flatten_element(element, prefix: str = '') -> dict[str, str]:
    data: dict[str, str] = {}
    if element is None:
        return data
    for child in element:
        tag = child.tag.split('}')[-1]
        key = f'{prefix}_{tag}' if prefix else tag
        text = (child.text or '').strip()
        if len(child):
            if text:
                data[key] = text
            data.update(flatten_element(child, key))
        elif text:
            data[key] = text
    return data

def parse_ssf(path: Path) -> dict[str, pd.DataFrame]:
    tree = ET.parse(path)
    root = tree.getroot()

    patient_df = pd.DataFrame([flatten_element(root.find('.//{*}patient'))])

    tumor_samples = [flatten_element(node) for node in root.findall('.//{*}tumor_sample')]
    tumor_locations = [flatten_element(node) for node in root.findall('.//{*}tumor_location')]
    tumor_histologies = [flatten_element(node) for node in root.findall('.//{*}tumor_histology')]
    normal_controls = [flatten_element(node) for node in root.findall('.//{*}normal_control')]

    return {
        'patient': patient_df,
        'tumor_samples': pd.DataFrame(tumor_samples),
        'tumor_locations': pd.DataFrame(tumor_locations),
        'tumor_histologies': pd.DataFrame(tumor_histologies),
        'normal_controls': pd.DataFrame(normal_controls),
    }

ssf_path = Path(ssf_index.loc[0, 'path'])
ssf_tables = parse_ssf(ssf_path)
print(f'Sample SSF file: {ssf_path.name}')
for table_name, df in ssf_tables.items():
    print(f"{table_name.replace('_', ' ').title()} rows: {len(df)}")
    if not df.empty:
        display(df.head())
# Out:
# Sample SSF file: nationwidechildrens.org_ssf.TCGA-BH-A0BD.xml
# Patient rows: 1
#   bcr_patient_barcode                      bcr_patient_uuid  \
# 0        TCGA-BH-A0BD  b379bfb8-284e-4300-8325-85cfd6809cb8
#
#   tissue_source_site patient_id tumor_samples_tumor_sample_bcr_sample_uuid  \
# 0                 BH       A0BD       832b8766-0e59-4ad4-b4c9-1e39b2ce4fb1
#
#   tumor_samples_tumor_sample_days_to_sample_procurement  \
# 0                                                 16
#
#   tumor_samples_tumor_sample_method_of_sample_procurement  \
# 0                              Other Method, specify
#
#   tumor_samples_tumor_sample_other_method_of_sample_procurement  \
# 0                               SEGMENTAL MASTECTOMY
#
#   tumor_samples_tumor_sample_vessel_used  \
# 0                                  Other
#
#   tumor_samples_tumor_sample_other_vessel_used  ...  \
# 0            FISHERBRAND SPECIMEN STORAGE BAGS  ...
#
#   tumor_samples_tumor_sample_digital_image_submitted  \
# 0                                                 NO
#
#   tumor_samples_tumor_sample_ffpe_tumor_slide_submitted  \
# 0                                                 NO
#
#   tumor_samples_tumor_sample_other_dx  \
# 0                                  No
#
#   tumor_samples_tumor_sample_history_of_neoadjuvant_treatment  \
# 0                                                 No
#
#   tumor_samples_tumor_sample_consent_or_death_status  \
# 0                                          Consented
#
#   tumor_samples_tumor_sample_days_to_consent  \
# 0                                          5
#
#   tumor_samples_tumor_sample_tumor_histologies_tumor_histology_histological_type  \
# 0                      Infiltrating Ductal Carcinoma
#
#   tumor_samples_tumor_sample_tumor_locations_laterality  \
# 0                                               Left
#
#   tumor_samples_tumor_sample_tumor_locations_tumor_location_site_of_disease  \
# 0                                             Breast
#
#   normal_controls_normal_control_bcr_sample_uuid
# 0           b4ff4763-e3a8-4e6a-bd4e-a6b1e1b722a0
#
# [1 rows x 30 columns]
# Tumor Samples rows: 1
#                         bcr_sample_uuid days_to_sample_procurement  \
# 0  832b8766-0e59-4ad4-b4c9-1e39b2ce4fb1                         16
#
#   method_of_sample_procurement other_method_of_sample_procurement vessel_used  \
# 0        Other Method, specify               SEGMENTAL MASTECTOMY       Other
#
#                    other_vessel_used tumor_weight sample_prescreened  \
# 0  FISHERBRAND SPECIMEN STORAGE BAGS          100                YES
#
#   tumor_nuclei_percent tumor_necrosis_percent  ... top_slide_submitted  \
# 0                   70                     30  ...                 YES
#
#   digital_image_submitted ffpe_tumor_slide_submitted other_dx  \
# 0                      NO                         NO       No
#
#   history_of_neoadjuvant_treatment consent_or_death_status days_to_consent  \
# 0                               No               Consented               5
#
#   tumor_histologies_tumor_histology_histological_type  \
# 0                      Infiltrating Ductal Carcinoma
#
#   tumor_locations_laterality tumor_locations_tumor_location_site_of_disease
# 0                       Left                                         Breast
#
# [1 rows x 25 columns]
# Tumor Locations rows: 1
#   site_of_disease
# 0          Breast
# Tumor Histologies rows: 1
#                histological_type
# 0  Infiltrating Ductal Carcinoma
# Normal Controls rows: 1
#                         bcr_sample_uuid
# 0  b4ff4763-e3a8-4e6a-bd4e-a6b1e1b722a0

# %%
import json

# %%
expression_with_metadata.shape
# Out:
# (1197, 27)

# %%
expression_index.shape
# Out:
# (1197, 5)
